# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats as stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, precision_score, recall_score
from sklearn.model_selection import KFold
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# step 2. 데이터 탐색 및 시각화

# %%
df = pd.read_csv('dataset_null.csv')
df.head()
# Out:
#                   date  EX5.MELT_TEMP  EX4.MELT_TEMP  EX3.MELT_TEMP  \
# 0  2020 10 30 00:00:04          297.0            222            251
# 1  2020 10 30 00:00:09          297.0            222            251
# 2  2020 10 30 00:00:14          297.0            222            251
# 3  2020 10 30 00:00:19          297.0            222            251
# 4  2020 10 30 00:00:24          297.0            222            251
#
#    EX2.MELT_TEMP  EX1.Z1_PV  EX1.Z2_PV  EX1.Z3_PV  EX1.Z4_PV  EX1.A1_PV  \
# 0          267.0        209      219.0        229        239        240
# 1          268.0        210      219.0        229        239        240
# 2          267.0        210      219.0        229        239        240
# 3          267.0        210      219.0        229        240        240
# 4          267.0        210      219.0        229        239        240
#
#    EX1.A2_PV  EX1.H1_PV  EX1.H2_PV  EX1.H3_PV  EX1.H4_PV  EX1.H2O_PV  \
# 0        239        241        240        240         40          41
# 1        239        240        240        240         40          41
# 2        239        240        240        240         40          41
# 3        239        241        240        240         40          41
# 4        239        241        240        240         40          41
#
#    EX1.MELT_P_PV  EX1.MD_PV  EX1.MD_TQ  passorfail
# 0            0.0    71.2215         72         0.0
# 1            0.0    71.2096         72         0.0
# 2            0.0    71.1977         72         0.0
# 3            0.0    71.1977         72         0.0
# 4            0.0    71.1977         72         0.0

# %%
df1 = df.drop(['date'], axis=1, inplace=False)
df1.head()
# Out:
#    EX5.MELT_TEMP  EX4.MELT_TEMP  EX3.MELT_TEMP  EX2.MELT_TEMP  EX1.Z1_PV  \
# 0          297.0            222            251          267.0        209
# 1          297.0            222            251          268.0        210
# 2          297.0            222            251          267.0        210
# 3          297.0            222            251          267.0        210
# 4          297.0            222            251          267.0        210
#
#    EX1.Z2_PV  EX1.Z3_PV  EX1.Z4_PV  EX1.A1_PV  EX1.A2_PV  EX1.H1_PV  \
# 0      219.0        229        239        240        239        241
# 1      219.0        229        239        240        239        240
# 2      219.0        229        239        240        239        240
# 3      219.0        229        240        240        239        241
# 4      219.0        229        239        240        239        241
#
#    EX1.H2_PV  EX1.H3_PV  EX1.H4_PV  EX1.H2O_PV  EX1.MELT_P_PV  EX1.MD_PV  \
# 0        240        240         40          41            0.0    71.2215
# 1        240        240         40          41            0.0    71.2096
# 2        240        240         40          41            0.0    71.1977
# 3        240        240         40          41            0.0    71.1977
# 4        240        240         40          41            0.0    71.1977
#
#    EX1.MD_TQ  passorfail
# 0         72         0.0
# 1         72         0.0
# 2         72         0.0
# 3         72         0.0
# 4         72         0.0

# %%
df1.columns
# Out:
# Index(['EX5.MELT_TEMP', 'EX4.MELT_TEMP', 'EX3.MELT_TEMP', 'EX2.MELT_TEMP',
#        'EX1.Z1_PV', 'EX1.Z2_PV', 'EX1.Z3_PV', 'EX1.Z4_PV', 'EX1.A1_PV',
#        'EX1.A2_PV', 'EX1.H1_PV', 'EX1.H2_PV', 'EX1.H3_PV', 'EX1.H4_PV',
#        'EX1.H2O_PV', 'EX1.MELT_P_PV', 'EX1.MD_PV', 'EX1.MD_TQ', 'passorfail'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17280 entries, 0 to 17279
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EX5.MELT_TEMP  17261 non-null  float64
#  1   EX4.MELT_TEMP  17280 non-null  int64
#  2   EX3.MELT_TEMP  17280 non-null  int64
#  3   EX2.MELT_TEMP  17268 non-null  float64
#  4   EX1.Z1_PV      17280 non-null  int64
#  5   EX1.Z2_PV      17265 non-null  float64
#  6   EX1.Z3_PV      17280 non-null  int64
#  7   EX1.Z4_PV      17280 non-null  int64
#  8   EX1.A1_PV      17280 non-null  int64
#  9   EX1.A2_PV      17280 non-null  int64
#  10  EX1.H1_PV      17280 non-null  int64
#  11  EX1.H2_PV      17280 non-null  int64
#  12  EX1.H3_PV      17280 non-null  int64
#  13  EX1.H4_PV      17280 non-null  int64
#  14  EX1.H2O_PV     17280 non-null  int64
#  15  EX1.MELT_P_PV  17280 non-null  float64
#  16  EX1.MD_PV      17280 non-null  float64
#  17  EX1.MD_TQ      17280 non-null  int64
#  18  passorfail     17257 non-null  float64
# dtypes: float64(6), int64(13)
# memory usage: 2.5 MB

# %%
df1.describe()
# Out:
#        EX5.MELT_TEMP  EX4.MELT_TEMP  EX3.MELT_TEMP  EX2.MELT_TEMP  \
# count   17261.000000   17280.000000   17280.000000   17268.000000
# mean      296.390765     221.892245     251.021470     266.929291
# std         0.588185       0.369363       0.637443       0.578102
# min       294.000000     219.000000     249.000000     265.000000
# 25%       296.000000     222.000000     251.000000     267.000000
# 50%       296.000000     222.000000     251.000000     267.000000
# 75%       297.000000     222.000000     251.000000     267.000000
# max       300.000000     223.000000     253.000000     269.000000
#
#           EX1.Z1_PV     EX1.Z2_PV     EX1.Z3_PV     EX1.Z4_PV     EX1.A1_PV  \
# count  17280.000000  17265.000000  17280.000000  17280.000000  17280.000000
# mean     209.786516    219.619056    229.677951    239.676273    239.576100
# std        1.628204      0.496368      0.473549      0.477824      0.501628
# min      201.000000    217.000000    228.000000    237.000000    239.000000
# 25%      209.000000    219.000000    229.000000    239.000000    239.000000
# 50%      210.000000    220.000000    230.000000    240.000000    240.000000
# 75%      210.000000    220.000000    230.000000    240.000000    240.000000
# max      218.000000    221.000000    232.000000    242.000000    241.000000
#
#           EX1.A2_PV     EX1.H1_PV     EX1.H2_PV     EX1.H3_PV     EX1.H4_PV  \
# count  17280.000000  17280.000000  17280.000000  17280.000000  17280.000000
# mean     239.572106    239.590278    239.599769    239.627199     40.372338
# std        0.586524      0.562705      0.529909      0.547126      1.802481
# min      237.000000    237.000000    237.000000    236.000000     35.000000
# 25%      239.000000    239.000000    239.000000    239.000000     39.000000
# 50%      240.000000    240.000000    240.000000    240.000000     40.000000
# 75%      240.000000    240.000000    240.000000    240.000000     42.000000
# max      242.000000    242.000000    241.000000    244.000000     44.000000
#
#          EX1.H2O_PV  EX1.MELT_P_PV     EX1.MD_PV     EX1.MD_TQ    passorfail
# count  17280.000000   17280.000000  17280.000000  17280.000000  17257.000000
# mean      42.125637       6.010608     70.897139     71.895833      0.006374
# std        3.367409       5.914024      4.494657      2.736710      0.079586
# min       37.000000       0.000000      0.000000      0.000000      0.000000
# 25%       39.000000       0.000000     71.185800     72.000000      0.000000
# 50%       42.000000       4.812500     71.197700     72.000000      0.000000
# 75%       45.000000      10.062500     71.209600     72.000000      0.000000
# max       49.000000      22.662500     75.612600     72.000000      1.000000

# %%
df1.shape
# Out:
# (17280, 19)

# %%
df1.isnull().sum()
# Out:
# EX5.MELT_TEMP    19
# EX4.MELT_TEMP     0
# EX3.MELT_TEMP     0
# EX2.MELT_TEMP    12
# EX1.Z1_PV         0
# EX1.Z2_PV        15
# EX1.Z3_PV         0
# EX1.Z4_PV         0
# EX1.A1_PV         0
# EX1.A2_PV         0
# EX1.H1_PV         0
# EX1.H2_PV         0
# EX1.H3_PV         0
# EX1.H4_PV         0
# EX1.H2O_PV        0
# EX1.MELT_P_PV     0
# EX1.MD_PV         0
# EX1.MD_TQ         0
# passorfail       23
# dtype: int64

# %%
fail = df1[df1.passorfail == 1].shape[0]
normal = df1[df1.passorfail == 0].shape[0]
fail_rate = (fail/(fail+normal))*100
print(f'양품 수: {normal} 불량 수: {fail}\n불량률: {fail_rate}')
# Out:
# 양품 수: 17147 불량 수: 110
# 불량률: 0.6374224952193313

# %%
df1.hist(figsize=(25,20))
plt.show()

# %%
df2 = df1.astype(float)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17280 entries, 0 to 17279
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EX5.MELT_TEMP  17261 non-null  float64
#  1   EX4.MELT_TEMP  17280 non-null  float64
#  2   EX3.MELT_TEMP  17280 non-null  float64
#  3   EX2.MELT_TEMP  17268 non-null  float64
#  4   EX1.Z1_PV      17280 non-null  float64
#  5   EX1.Z2_PV      17265 non-null  float64
#  6   EX1.Z3_PV      17280 non-null  float64
#  7   EX1.Z4_PV      17280 non-null  float64
#  8   EX1.A1_PV      17280 non-null  float64
#  9   EX1.A2_PV      17280 non-null  float64
#  10  EX1.H1_PV      17280 non-null  float64
#  11  EX1.H2_PV      17280 non-null  float64
#  12  EX1.H3_PV      17280 non-null  float64
#  13  EX1.H4_PV      17280 non-null  float64
#  14  EX1.H2O_PV     17280 non-null  float64
#  15  EX1.MELT_P_PV  17280 non-null  float64
#  16  EX1.MD_PV      17280 non-null  float64
#  17  EX1.MD_TQ      17280 non-null  float64
#  18  passorfail     17257 non-null  float64
# dtypes: float64(19)
# memory usage: 2.5 MB

# %%
df2 = df1.dropna(subset=["passorfail"])
df2.shape
# Out:
# (17257, 19)

# %% [markdown]
# step1. 트레인.테스트셋 분리 / 계층적 샘플링

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df2, test_size=0.2, random_state=42)

# %%
df2["EX1.H2O_PV_cat"] = pd.cut(df2["EX1.H2O_PV"],
                               bins=[36, 37, 39, 42, 45, 47, np.inf],
                               labels=[1, 2, 3, 4, 5, 6])
df2.head()
# Out:
#    EX5.MELT_TEMP  EX4.MELT_TEMP  EX3.MELT_TEMP  EX2.MELT_TEMP  EX1.Z1_PV  \
# 0          297.0            222            251          267.0        209
# 1          297.0            222            251          268.0        210
# 2          297.0            222            251          267.0        210
# 3          297.0            222            251          267.0        210
# 4          297.0            222            251          267.0        210
#
#    EX1.Z2_PV  EX1.Z3_PV  EX1.Z4_PV  EX1.A1_PV  EX1.A2_PV  EX1.H1_PV  \
# 0      219.0        229        239        240        239        241
# 1      219.0        229        239        240        239        240
# 2      219.0        229        239        240        239        240
# 3      219.0        229        240        240        239        241
# 4      219.0        229        239        240        239        241
#
#    EX1.H2_PV  EX1.H3_PV  EX1.H4_PV  EX1.H2O_PV  EX1.MELT_P_PV  EX1.MD_PV  \
# 0        240        240         40          41            0.0    71.2215
# 1        240        240         40          41            0.0    71.2096
# 2        240        240         40          41            0.0    71.1977
# 3        240        240         40          41            0.0    71.1977
# 4        240        240         40          41            0.0    71.1977
#
#    EX1.MD_TQ  passorfail EX1.H2O_PV_cat
# 0         72         0.0              3
# 1         72         0.0              3
# 2         72         0.0              3
# 3         72         0.0              3
# 4         72         0.0              3

# %%
df2["EX1.H2O_PV_cat"].value_counts().sort_index().plot.bar(rot=0, grid=True)
plt.xlabel("EX1.H2O_PV_cat")
plt.ylabel("Number of districts")
plt.show()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17257 entries, 0 to 17263
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EX5.MELT_TEMP   17238 non-null  float64
#  1   EX4.MELT_TEMP   17257 non-null  int64
#  2   EX3.MELT_TEMP   17257 non-null  int64
#  3   EX2.MELT_TEMP   17245 non-null  float64
#  4   EX1.Z1_PV       17257 non-null  int64
#  5   EX1.Z2_PV       17242 non-null  float64
#  6   EX1.Z3_PV       17257 non-null  int64
#  7   EX1.Z4_PV       17257 non-null  int64
#  8   EX1.A1_PV       17257 non-null  int64
#  9   EX1.A2_PV       17257 non-null  int64
#  10  EX1.H1_PV       17257 non-null  int64
#  11  EX1.H2_PV       17257 non-null  int64
#  12  EX1.H3_PV       17257 non-null  int64
#  13  EX1.H4_PV       17257 non-null  int64
#  14  EX1.H2O_PV      17257 non-null  int64
#  15  EX1.MELT_P_PV   17257 non-null  float64
#  16  EX1.MD_PV       17257 non-null  float64
#  17  EX1.MD_TQ       17257 non-null  int64
#  18  passorfail      17257 non-null  float64
#  19  EX1.H2O_PV_cat  17257 non-null  category
# dtypes: category(1), float64(6), int64(13)
# memory usage: 2.6 MB

# %%
strat_train_set, strat_test_set = train_test_split(df2, test_size=0.2, stratify = df2["EX1.H2O_PV_cat"], random_state=42)

# %%
strat_train_set.head()
# Out:
#        EX5.MELT_TEMP  EX4.MELT_TEMP  EX3.MELT_TEMP  EX2.MELT_TEMP  EX1.Z1_PV  \
# 6444           296.0            222            251          266.0        209
# 14017          296.0            222            251          267.0        209
# 3582           296.0            222            251          266.0        210
# 12737          296.0            222            251          267.0        209
# 15964          296.0            223            249          265.0        209
#
#        EX1.Z2_PV  EX1.Z3_PV  EX1.Z4_PV  EX1.A1_PV  EX1.A2_PV  EX1.H1_PV  \
# 6444       220.0        230        240        240        240        240
# 14017      220.0        229        240        239        239        240
# 3582       219.0        230        240        240        240        240
# 12737      220.0        230        240        240        239        240
# 15964      219.0        229        239        239        241        238
#
#        EX1.H2_PV  EX1.H3_PV  EX1.H4_PV  EX1.H2O_PV  EX1.MELT_P_PV  EX1.MD_PV  \
# 6444         240        240         38          38         0.6563    71.2096
# 14017        240        240         42          45         4.5063    71.2096
# 3582         240        240         39          39         4.7688    71.1977
# 12737        240        240         43          49        10.3250    71.1977
# 15964        239        239         38          41         7.0438    71.1977
#
#        EX1.MD_TQ  passorfail EX1.H2O_PV_cat
# 6444          72         0.0              2
# 14017         72         0.0              4
# 3582          72         0.0              2
# 12737         72         0.0              6
# 15964         72         0.0              3

# %%
strat_test_set["EX1.H2O_PV_cat"].value_counts() / len(strat_test_set)
# Out:
# 3    0.293743
# 2    0.231170
# 4    0.200753
# 5    0.189455
# 1    0.050985
# 6    0.033893
# Name: EX1.H2O_PV_cat, dtype: float64

# %%
def acceration_cat_proportions(data):
    return data["EX1.H2O_PV_cat"].value_counts() / len(data)

train_set, test_set = train_test_split(df2, test_size=0.2, random_state=42)

compare_props = pd.DataFrame({
    "Overall %": acceration_cat_proportions(df2),
    "Stratified %": acceration_cat_proportions(strat_test_set),
    "Random %": acceration_cat_proportions(test_set),
}).sort_index()
compare_props.index.name = "EX1.H2O_PV_category"
compare_props["Strat. Error %"] = (compare_props["Stratified %"] /
                                   compare_props["Overall %"] - 1)
compare_props["Rand. Error %"] = (compare_props["Random %"] /
                                  compare_props["Overall %"] - 1)
(compare_props * 100).round(2)
# Out:
#                      Overall %  Stratified %  Random %  Strat. Error %  \
# EX1.H2O_PV_category
# 1                         5.10          5.10      4.84           -0.02
# 2                        23.10         23.12     22.68            0.06
# 3                        29.39         29.37     29.20           -0.04
# 4                        20.07         20.08     20.86            0.01
# 5                        18.96         18.95     19.09           -0.08
# 6                         3.38          3.39      3.33            0.33
#
#                      Rand. Error %
# EX1.H2O_PV_category
# 1                            -5.13
# 2                            -1.82
# 3                            -0.63
# 4                             3.91
# 5                             0.69
# 6                            -1.39

# %%
for set_ in (strat_train_set, strat_test_set):
    set_.drop("EX1.H2O_PV_cat", axis=1, inplace=True)
    
df_train = strat_train_set.copy()

# %%
df_train.head()
# Out:
#        EX5.MELT_TEMP  EX4.MELT_TEMP  EX3.MELT_TEMP  EX2.MELT_TEMP  EX1.Z1_PV  \
# 6444           296.0            222            251          266.0        209
# 14017          296.0            222            251          267.0        209
# 3582           296.0            222            251          266.0        210
# 12737          296.0            222            251          267.0        209
# 15964          296.0            223            249          265.0        209
#
#        EX1.Z2_PV  EX1.Z3_PV  EX1.Z4_PV  EX1.A1_PV  EX1.A2_PV  EX1.H1_PV  \
# 6444       220.0        230        240        240        240        240
# 14017      220.0        229        240        239        239        240
# 3582       219.0        230        240        240        240        240
# 12737      220.0        230        240        240        239        240
# 15964      219.0        229        239        239        241        238
#
#        EX1.H2_PV  EX1.H3_PV  EX1.H4_PV  EX1.H2O_PV  EX1.MELT_P_PV  EX1.MD_PV  \
# 6444         240        240         38          38         0.6563    71.2096
# 14017        240        240         42          45         4.5063    71.2096
# 3582         240        240         39          39         4.7688    71.1977
# 12737        240        240         43          49        10.3250    71.1977
# 15964        239        239         38          41         7.0438    71.1977
#
#        EX1.MD_TQ  passorfail
# 6444          72         0.0
# 14017         72         0.0
# 3582          72         0.0
# 12737         72         0.0
# 15964         72         0.0

# %% [markdown]
# 3. 상관분석

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = df2.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <Axes: >

# %%
corr_matrix = df2.corr()
corr_matrix
# Out:
#                EX5.MELT_TEMP  EX4.MELT_TEMP  EX3.MELT_TEMP  EX2.MELT_TEMP  \
# EX5.MELT_TEMP       1.000000       0.110536      -0.313956       0.173882
# EX4.MELT_TEMP       0.110536       1.000000      -0.280022      -0.173232
# EX3.MELT_TEMP      -0.313956      -0.280022       1.000000       0.298691
# EX2.MELT_TEMP       0.173882      -0.173232       0.298691       1.000000
# EX1.Z1_PV          -0.032455      -0.019417      -0.003629       0.005620
# EX1.Z2_PV          -0.104826       0.007862      -0.015347      -0.018096
# EX1.Z3_PV           0.005301       0.005620      -0.031016       0.013976
# EX1.Z4_PV          -0.067793       0.000970       0.003622       0.011912
# EX1.A1_PV           0.039234      -0.004220       0.030747       0.101029
# EX1.A2_PV          -0.014658       0.054844      -0.031935      -0.170242
# EX1.H1_PV           0.030025       0.057530       0.091559       0.011167
# EX1.H2_PV          -0.010686       0.018756       0.072966       0.052281
# EX1.H3_PV          -0.067822       0.086175       0.034807      -0.057293
# EX1.H4_PV          -0.413944      -0.332247       0.256753      -0.053807
# EX1.H2O_PV         -0.489426      -0.216749       0.178879      -0.083772
# EX1.MELT_P_PV      -0.541407      -0.122941       0.117312      -0.193483
# EX1.MD_PV           0.033365       0.171986      -0.063392       0.026257
# EX1.MD_TQ          -0.101646       0.083716      -0.001161      -0.004664
# passorfail         -0.054483      -0.157911       0.068267      -0.030487
#
#                EX1.Z1_PV  EX1.Z2_PV  EX1.Z3_PV  EX1.Z4_PV  EX1.A1_PV  \
# EX5.MELT_TEMP  -0.032455  -0.104826   0.005301  -0.067793   0.039234
# EX4.MELT_TEMP  -0.019417   0.007862   0.005620   0.000970  -0.004220
# EX3.MELT_TEMP  -0.003629  -0.015347  -0.031016   0.003622   0.030747
# EX2.MELT_TEMP   0.005620  -0.018096   0.013976   0.011912   0.101029
# EX1.Z1_PV       1.000000   0.306997   0.149727  -0.017092   0.042562
# EX1.Z2_PV       0.306997   1.000000   0.238708   0.249859   0.024139
# EX1.Z3_PV       0.149727   0.238708   1.000000   0.319958   0.113285
# EX1.Z4_PV      -0.017092   0.249859   0.319958   1.000000   0.055994
# EX1.A1_PV       0.042562   0.024139   0.113285   0.055994   1.000000
# EX1.A2_PV      -0.047400  -0.004187   0.083962   0.136537  -0.153904
# EX1.H1_PV      -0.006189  -0.035163  -0.007114  -0.034082   0.217615
# EX1.H2_PV      -0.022597  -0.003869   0.007106   0.030555   0.182157
# EX1.H3_PV      -0.031440   0.122697   0.053708   0.085035   0.276034
# EX1.H4_PV       0.010156   0.062847   0.007017   0.012093   0.018286
# EX1.H2O_PV      0.045163   0.064148  -0.019125   0.006720  -0.018444
# EX1.MELT_P_PV  -0.001838   0.060271  -0.031204   0.014155  -0.000826
# EX1.MD_PV      -0.020797   0.095349   0.026440   0.077146   0.043934
# EX1.MD_TQ      -0.014495   0.158057   0.080216   0.111250   0.016382
# passorfail      0.015674  -0.080836  -0.011581  -0.063004  -0.042576
#
#                EX1.A2_PV  EX1.H1_PV  EX1.H2_PV  EX1.H3_PV  EX1.H4_PV  \
# EX5.MELT_TEMP  -0.014658   0.030025  -0.010686  -0.067822  -0.413944
# EX4.MELT_TEMP   0.054844   0.057530   0.018756   0.086175  -0.332247
# EX3.MELT_TEMP  -0.031935   0.091559   0.072966   0.034807   0.256753
# EX2.MELT_TEMP  -0.170242   0.011167   0.052281  -0.057293  -0.053807
# EX1.Z1_PV      -0.047400  -0.006189  -0.022597  -0.031440   0.010156
# EX1.Z2_PV      -0.004187  -0.035163  -0.003869   0.122697   0.062847
# EX1.Z3_PV       0.083962  -0.007114   0.007106   0.053708   0.007017
# EX1.Z4_PV       0.136537  -0.034082   0.030555   0.085035   0.012093
# EX1.A1_PV      -0.153904   0.217615   0.182157   0.276034   0.018286
# EX1.A2_PV       1.000000   0.007288  -0.031942  -0.094324  -0.025528
# EX1.H1_PV       0.007288   1.000000   0.526466   0.388794   0.032289
# EX1.H2_PV      -0.031942   0.526466   1.000000   0.416067   0.007988
# EX1.H3_PV      -0.094324   0.388794   0.416067   1.000000   0.064482
# EX1.H4_PV      -0.025528   0.032289   0.007988   0.064482   1.000000
# EX1.H2O_PV     -0.001508   0.035827   0.006899   0.036314   0.858745
# EX1.MELT_P_PV  -0.025916   0.010469   0.008099   0.075718   0.725306
# EX1.MD_PV      -0.032963  -0.002891   0.083267   0.229903  -0.095928
# EX1.MD_TQ      -0.014814  -0.011522   0.051695   0.160565  -0.052103
# passorfail      0.036117   0.005342  -0.089197  -0.208843   0.103346
#
#                EX1.H2O_PV  EX1.MELT_P_PV  EX1.MD_PV  EX1.MD_TQ  passorfail
# EX5.MELT_TEMP   -0.489426      -0.541407   0.033365  -0.101646   -0.054483
# EX4.MELT_TEMP   -0.216749      -0.122941   0.171986   0.083716   -0.157911
# EX3.MELT_TEMP    0.178879       0.117312  -0.063392  -0.001161    0.068267
# EX2.MELT_TEMP   -0.083772      -0.193483   0.026257  -0.004664   -0.030487
# EX1.Z1_PV        0.045163      -0.001838  -0.020797  -0.014495    0.015674
# EX1.Z2_PV        0.064148       0.060271   0.095349   0.158057   -0.080836
# EX1.Z3_PV       -0.019125      -0.031204   0.026440   0.080216   -0.011581
# EX1.Z4_PV        0.006720       0.014155   0.077146   0.111250   -0.063004
# EX1.A1_PV       -0.018444      -0.000826   0.043934   0.016382   -0.042576
# EX1.A2_PV       -0.001508      -0.025916  -0.032963  -0.014814    0.036117
# EX1.H1_PV        0.035827       0.010469  -0.002891  -0.011522    0.005342
# EX1.H2_PV        0.006899       0.008099   0.083267   0.051695   -0.089197
# EX1.H3_PV        0.036314       0.075718   0.229903   0.160565   -0.208843
# EX1.H4_PV        0.858745       0.725306  -0.095928  -0.052103    0.103346
# EX1.H2O_PV       1.000000       0.713895  -0.084398  -0.042434    0.090786
# EX1.MELT_P_PV    0.713895       1.000000  -0.080443  -0.043147    0.092513
# EX1.MD_PV       -0.084398      -0.080443   1.000000   0.600422   -0.877248
# EX1.MD_TQ       -0.042434      -0.043147   0.600422   1.000000   -0.475554
# passorfail       0.090786       0.092513  -0.877248  -0.475554    1.000000

# %%
corr_matrix["passorfail"].sort_values(ascending=False)
# Out:
# passorfail       1.000000
# EX1.H4_PV        0.103346
# EX1.MELT_P_PV    0.092513
# EX1.H2O_PV       0.090786
# EX3.MELT_TEMP    0.068267
# EX1.A2_PV        0.036117
# EX1.Z1_PV        0.015674
# EX1.H1_PV        0.005342
# EX1.Z3_PV       -0.011581
# EX2.MELT_TEMP   -0.030487
# EX1.A1_PV       -0.042576
# EX5.MELT_TEMP   -0.054483
# EX1.Z4_PV       -0.063004
# EX1.Z2_PV       -0.080836
# EX1.H2_PV       -0.089197
# EX4.MELT_TEMP   -0.157911
# EX1.H3_PV       -0.208843
# EX1.MD_TQ       -0.475554
# EX1.MD_PV       -0.877248
# Name: passorfail, dtype: float64

# %% [markdown]
# 4. 특성 조합으로 실험

# %%
df2 =

# %%
df2 = df1.drop(['passorfail'], axis=1, inplace=False)
df2 = df2.astype(float)
df2.info()
# Out:
#    EX5.MELT_TEMP  EX4.MELT_TEMP  EX3.MELT_TEMP  EX2.MELT_TEMP  EX1.Z1_PV  \
# 0          297.0          222.0          251.0          267.0      209.0
# 1          297.0          222.0          251.0          268.0      210.0
# 2          297.0          222.0          251.0          267.0      210.0
# 3          297.0          222.0          251.0          267.0      210.0
# 4          297.0          222.0          251.0          267.0      210.0
#
#    EX1.Z2_PV  EX1.Z3_PV  EX1.Z4_PV  EX1.A1_PV  EX1.A2_PV  EX1.H1_PV  \
# 0      219.0      229.0      239.0      240.0      239.0      241.0
# 1      219.0      229.0      239.0      240.0      239.0      240.0
# 2      219.0      229.0      239.0      240.0      239.0      240.0
# 3      219.0      229.0      240.0      240.0      239.0      241.0
# 4      219.0      229.0      239.0      240.0      239.0        NaN
#
#    EX1.H2_PV  EX1.H3_PV  EX1.H4_PV  EX1.H2O_PV  EX1.MELT_P_PV  EX1.MD_PV  \
# 0      240.0      240.0       40.0        41.0            0.0    71.2215
# 1      240.0      240.0       40.0        41.0            0.0    71.2096
# 2      240.0      240.0       40.0        41.0            0.0    71.1977
# 3      240.0      240.0       40.0        41.0            0.0    71.1977
# 4      240.0      240.0       40.0        41.0            0.0    71.1977
#
#    EX1.MD_TQ
# 0       72.0
# 1       72.0
# 2       72.0
# 3       72.0
# 4       72.0
