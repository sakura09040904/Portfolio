# %%
import pandas as pd

titanic_df=pd.read_csv("titanic.csv")
titanic_df.head()
# Out:
#    Unnamed: 0  Survived  Pclass     Sex   Age     Fare Embarked  Class  \
# 0           0         0       3    male  22.0   7.2500        S  Third
# 1           1         1       1  female  38.0  71.2833        C  First
# 2           2         1       3  female  26.0   7.9250        S  Third
# 3           3         1       1  female  35.0  53.1000        S  First
# 4           4         0       3    male  35.0   8.0500        S  Third
#
#    Adult_Male   Embarktown
# 0        True  Southampton
# 1       False    Cherbourg
# 2       False  Southampton
# 3       False  Southampton
# 4        True  Southampton

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 897 entries, 0 to 896
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  897 non-null    int64
#  1   Survived    897 non-null    int64
#  2   Pclass      897 non-null    int64
#  3   Sex         897 non-null    object
#  4   Age         897 non-null    float64
#  5   Fare        897 non-null    float64
#  6   Embarked    895 non-null    object
#  7   Class       897 non-null    object
#  8   Adult_Male  897 non-null    bool
#  9   Embarktown  895 non-null    object
# dtypes: bool(1), float64(2), int64(3), object(4)
# memory usage: 64.1+ KB

# %%
import seaborn as sns

sns.catplot(x='Sex', hue='Survived', kind='count', data=titanic_df)

# %%
titanic_df.tail(10)
# Out:
#      Unnamed: 0  Survived  Pclass     Sex        Age   Fare Embarked  Class  \
# 887         887         1       1  female  19.000000  30.00        S  First
# 888         888         0       3  female  29.699118  23.45        S  Third
# 889         889         1       1    male  26.000000  30.00        C  First
# 890         890         0       3    male  32.000000   7.75        Q  Third
# 891         890         0       3    male  32.000000   7.75        Q  Third
# 892         890         0       3    male  32.000000   7.75        Q  Third
# 893         890         0       3    male  32.000000   7.75        Q  Third
# 894         890         0       3    male  32.000000   7.75        Q  Third
# 895         890         0       3    male  32.000000   7.75        Q  Third
# 896         890         0       3    male  32.000000   7.75        Q  Third
#
#      Adult_Male   Embarktown
# 887       False  Southampton
# 888       False  Southampton
# 889        True    Cherbourg
# 890        True   Queenstown
# 891        True   Queenstown
# 892        True   Queenstown
# 893        True   Queenstown
# 894        True   Queenstown
# 895        True   Queenstown
# 896        True   Queenstown

# %%
titanic_df.drop_duplicates(inplace=True)
titanic_df[titanic_df.duplicated()]
titanic_df.tail(10)
# Out:
#      Unnamed: 0  Survived  Pclass     Sex        Age     Fare Embarked  \
# 881         881         0       3    male  33.000000   7.8958        S
# 882         882         0       3  female  22.000000  10.5167        S
# 883         883         0       2    male  28.000000  10.5000        S
# 884         884         0       3    male  25.000000   7.0500        S
# 885         885         0       3  female  39.000000  29.1250        Q
# 886         886         0       2    male  27.000000  13.0000        S
# 887         887         1       1  female  19.000000  30.0000        S
# 888         888         0       3  female  29.699118  23.4500        S
# 889         889         1       1    male  26.000000  30.0000        C
# 890         890         0       3    male  32.000000   7.7500        Q
#
#       Class  Adult_Male   Embarktown
# 881   Third        True  Southampton
# 882   Third       False  Southampton
# 883  Second        True  Southampton
# 884   Third        True  Southampton
# 885   Third       False   Queenstown
# 886  Second        True  Southampton
# 887   First       False  Southampton
# 888   Third       False  Southampton
# 889   First        True    Cherbourg
# 890   Third        True   Queenstown

# %%
titanic_df.drop(columns=['Embarked'], inplace=True)
titanic_df.head()
# Out:
#    Unnamed: 0  Survived  Pclass     Sex   Age     Fare  Class  Adult_Male  \
# 0           0         0       3    male  22.0   7.2500  Third        True
# 1           1         1       1  female  38.0  71.2833  First       False
# 2           2         1       3  female  26.0   7.9250  Third       False
# 3           3         1       1  female  35.0  53.1000  First       False
# 4           4         0       3    male  35.0   8.0500  Third        True
#
#     Embarktown
# 0  Southampton
# 1    Cherbourg
# 2  Southampton
# 3  Southampton
# 4  Southampton

# %%
titanic_df.isnull().sum()
# Out:
# Unnamed: 0    0
# Survived      0
# Pclass        0
# Sex           0
# Age           0
# Fare          0
# Class         0
# Adult_Male    0
# Embarktown    2
# dtype: int64
