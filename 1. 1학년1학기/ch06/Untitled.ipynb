# %%
# coding: utf-8
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.09666666666666666, test acc:0.0908
# epoch:1, train acc:0.12333333333333334, test acc:0.1063
# epoch:2, train acc:0.16666666666666666, test acc:0.132
# epoch:3, train acc:0.20666666666666667, test acc:0.1564
# epoch:4, train acc:0.25333333333333335, test acc:0.1848
# epoch:5, train acc:0.2733333333333333, test acc:0.2024
# epoch:6, train acc:0.31, test acc:0.2273
# epoch:7, train acc:0.36333333333333334, test acc:0.2433
# epoch:8, train acc:0.36333333333333334, test acc:0.2573
# epoch:9, train acc:0.37666666666666665, test acc:0.2557
# epoch:10, train acc:0.3566666666666667, test acc:0.2623
# epoch:11, train acc:0.43, test acc:0.2968
# epoch:12, train acc:0.44666666666666666, test acc:0.3152
# epoch:13, train acc:0.46, test acc:0.341
# epoch:14, train acc:0.48333333333333334, test acc:0.3509
# epoch:15, train acc:0.5566666666666666, test acc:0.3837
# epoch:16, train acc:0.5566666666666666, test acc:0.4063
# epoch:17, train acc:0.5533333333333333, test acc:0.411
# epoch:18, train acc:0.5533333333333333, test acc:0.4083
# epoch:19, train acc:0.53, test acc:0.408
# epoch:20, train acc:0.5666666666666667, test acc:0.4316
# epoch:21, train acc:0.5833333333333334, test acc:0.4466
# epoch:22, train acc:0.5966666666666667, test acc:0.4566
# epoch:23, train acc:0.6366666666666667, test acc:0.487
# epoch:24, train acc:0.63, test acc:0.4755
# epoch:25, train acc:0.6333333333333333, test acc:0.4716
# epoch:26, train acc:0.6366666666666667, test acc:0.4848
# epoch:27, train acc:0.66, test acc:0.4986
# epoch:28, train acc:0.67, test acc:0.5047
# epoch:29, train acc:0.6766666666666666, test acc:0.5226
# epoch:30, train acc:0.6866666666666666, test acc:0.5228
# epoch:31, train acc:0.6766666666666666, test acc:0.5184
# epoch:32, train acc:0.69, test acc:0.5332
# epoch:33, train acc:0.6833333333333333, test acc:0.5396
# epoch:34, train acc:0.6933333333333334, test acc:0.5492
# epoch:35, train acc:0.6933333333333334, test acc:0.5544
# epoch:36, train acc:0.6966666666666667, test acc:0.5405
# epoch:37, train acc:0.7, test acc:0.5423
# epoch:38, train acc:0.7133333333333334, test acc:0.5605
# epoch:39, train acc:0.7066666666666667, test acc:0.5497
# epoch:40, train acc:0.7166666666666667, test acc:0.5724
# epoch:41, train acc:0.7166666666666667, test acc:0.5631
# epoch:42, train acc:0.7133333333333334, test acc:0.5601
# epoch:43, train acc:0.73, test acc:0.5714
# epoch:44, train acc:0.73, test acc:0.5828
# epoch:45, train acc:0.7466666666666667, test acc:0.5962
# epoch:46, train acc:0.7533333333333333, test acc:0.5991
# epoch:47, train acc:0.7533333333333333, test acc:0.589
# epoch:48, train acc:0.7433333333333333, test acc:0.575
# epoch:49, train acc:0.78, test acc:0.5911
# epoch:50, train acc:0.77, test acc:0.6007
# epoch:51, train acc:0.7933333333333333, test acc:0.5978
# epoch:52, train acc:0.7866666666666666, test acc:0.5943
# epoch:53, train acc:0.79, test acc:0.6037
# epoch:54, train acc:0.78, test acc:0.5924
# epoch:55, train acc:0.81, test acc:0.6103
# epoch:56, train acc:0.8133333333333334, test acc:0.6146
# epoch:57, train acc:0.8133333333333334, test acc:0.6178
# epoch:58, train acc:0.8133333333333334, test acc:0.6139
# epoch:59, train acc:0.8266666666666667, test acc:0.6215
# epoch:60, train acc:0.8266666666666667, test acc:0.6214
# epoch:61, train acc:0.8233333333333334, test acc:0.6173
# epoch:62, train acc:0.8333333333333334, test acc:0.629
# epoch:63, train acc:0.8366666666666667, test acc:0.632
# epoch:64, train acc:0.84, test acc:0.6308
# epoch:65, train acc:0.83, test acc:0.6317
# epoch:66, train acc:0.83, test acc:0.642
# epoch:67, train acc:0.85, test acc:0.6464
# epoch:68, train acc:0.8533333333333334, test acc:0.6523
# epoch:69, train acc:0.8433333333333334, test acc:0.6403
# epoch:70, train acc:0.8533333333333334, test acc:0.6498
# epoch:71, train acc:0.8533333333333334, test acc:0.6442
# epoch:72, train acc:0.8566666666666667, test acc:0.6474
# epoch:73, train acc:0.8733333333333333, test acc:0.6582
# epoch:74, train acc:0.8633333333333333, test acc:0.6588
# epoch:75, train acc:0.8366666666666667, test acc:0.6527
# epoch:76, train acc:0.85, test acc:0.6601
# epoch:77, train acc:0.8366666666666667, test acc:0.6505
# epoch:78, train acc:0.8666666666666667, test acc:0.6597
# epoch:79, train acc:0.8666666666666667, test acc:0.6655
# epoch:80, train acc:0.87, test acc:0.6685
# epoch:81, train acc:0.87, test acc:0.6684
# epoch:82, train acc:0.8733333333333333, test acc:0.6739
# epoch:83, train acc:0.8766666666666667, test acc:0.6734
# epoch:84, train acc:0.8833333333333333, test acc:0.6743
# epoch:85, train acc:0.8733333333333333, test acc:0.6748
# epoch:86, train acc:0.8766666666666667, test acc:0.6727
# epoch:87, train acc:0.87, test acc:0.6713
# epoch:88, train acc:0.86, test acc:0.6612
# epoch:89, train acc:0.87, test acc:0.6732
# epoch:90, train acc:0.87, test acc:0.6681
# epoch:91, train acc:0.8633333333333333, test acc:0.6723
# epoch:92, train acc:0.8666666666666667, test acc:0.6773
# epoch:93, train acc:0.8666666666666667, test acc:0.671
# epoch:94, train acc:0.88, test acc:0.6819
# epoch:95, train acc:0.8666666666666667, test acc:0.6768
# epoch:96, train acc:0.8766666666666667, test acc:0.6796
# epoch:97, train acc:0.8866666666666667, test acc:0.681
# epoch:98, train acc:0.9033333333333333, test acc:0.6876
# epoch:99, train acc:0.8733333333333333, test acc:0.6814
# epoch:100, train acc:0.8833333333333333, test acc:0.6814
# epoch:101, train acc:0.8833333333333333, test acc:0.6818
# epoch:102, train acc:0.8966666666666666, test acc:0.6845
# epoch:103, train acc:0.89, test acc:0.6803
# epoch:104, train acc:0.8933333333333333, test acc:0.6818
# epoch:105, train acc:0.9033333333333333, test acc:0.6933
# epoch:106, train acc:0.9, test acc:0.6884
# epoch:107, train acc:0.89, test acc:0.6879
# epoch:108, train acc:0.8733333333333333, test acc:0.6824
# epoch:109, train acc:0.89, test acc:0.6899
# epoch:110, train acc:0.9, test acc:0.69
# epoch:111, train acc:0.9133333333333333, test acc:0.6968
# epoch:112, train acc:0.8966666666666666, test acc:0.6951
# epoch:113, train acc:0.8966666666666666, test acc:0.6963
# epoch:114, train acc:0.8966666666666666, test acc:0.7002
# epoch:115, train acc:0.8933333333333333, test acc:0.6862
# epoch:116, train acc:0.8833333333333333, test acc:0.6859
# epoch:117, train acc:0.9, test acc:0.692
# epoch:118, train acc:0.9, test acc:0.6945
# epoch:119, train acc:0.88, test acc:0.6887
# epoch:120, train acc:0.89, test acc:0.6892
# epoch:121, train acc:0.89, test acc:0.6995
# epoch:122, train acc:0.9033333333333333, test acc:0.6925
# epoch:123, train acc:0.8966666666666666, test acc:0.6936
# epoch:124, train acc:0.8933333333333333, test acc:0.7001
# epoch:125, train acc:0.8866666666666667, test acc:0.6967
# epoch:126, train acc:0.89, test acc:0.6951
# epoch:127, train acc:0.8966666666666666, test acc:0.6992
# epoch:128, train acc:0.9033333333333333, test acc:0.7027
# epoch:129, train acc:0.9033333333333333, test acc:0.699
# epoch:130, train acc:0.8833333333333333, test acc:0.6896
# epoch:131, train acc:0.8866666666666667, test acc:0.6983
# epoch:132, train acc:0.8966666666666666, test acc:0.6865
# epoch:133, train acc:0.8933333333333333, test acc:0.6935
# epoch:134, train acc:0.8966666666666666, test acc:0.7031
# epoch:135, train acc:0.8966666666666666, test acc:0.6992
# epoch:136, train acc:0.9033333333333333, test acc:0.6987
# epoch:137, train acc:0.8933333333333333, test acc:0.7012
# epoch:138, train acc:0.8966666666666666, test acc:0.6959
# epoch:139, train acc:0.8966666666666666, test acc:0.6887
# epoch:140, train acc:0.9033333333333333, test acc:0.696
# epoch:141, train acc:0.8966666666666666, test acc:0.6898
# epoch:142, train acc:0.8966666666666666, test acc:0.6965
# epoch:143, train acc:0.8966666666666666, test acc:0.6894
# epoch:144, train acc:0.8933333333333333, test acc:0.6916
# epoch:145, train acc:0.8833333333333333, test acc:0.6955
# epoch:146, train acc:0.9066666666666666, test acc:0.7006
# epoch:147, train acc:0.8966666666666666, test acc:0.6993
# epoch:148, train acc:0.9, test acc:0.7007
# epoch:149, train acc:0.8966666666666666, test acc:0.7004
# epoch:150, train acc:0.87, test acc:0.6925
# epoch:151, train acc:0.88, test acc:0.6967
# epoch:152, train acc:0.88, test acc:0.6977
# epoch:153, train acc:0.8966666666666666, test acc:0.7003
# epoch:154, train acc:0.8866666666666667, test acc:0.6956
# epoch:155, train acc:0.8866666666666667, test acc:0.7064
# epoch:156, train acc:0.8933333333333333, test acc:0.7001
# epoch:157, train acc:0.9033333333333333, test acc:0.7012
# epoch:158, train acc:0.8966666666666666, test acc:0.7024
# epoch:159, train acc:0.9033333333333333, test acc:0.7004
# epoch:160, train acc:0.9, test acc:0.699
# epoch:161, train acc:0.91, test acc:0.7025
# epoch:162, train acc:0.9, test acc:0.7038
# epoch:163, train acc:0.91, test acc:0.6989
# epoch:164, train acc:0.8966666666666666, test acc:0.7074
# epoch:165, train acc:0.8933333333333333, test acc:0.7043
# epoch:166, train acc:0.89, test acc:0.6969
# epoch:167, train acc:0.9, test acc:0.6976
# epoch:168, train acc:0.8833333333333333, test acc:0.6916
# epoch:169, train acc:0.89, test acc:0.6988
# epoch:170, train acc:0.8933333333333333, test acc:0.6954
# epoch:171, train acc:0.8966666666666666, test acc:0.703
# epoch:172, train acc:0.9033333333333333, test acc:0.7024
# epoch:173, train acc:0.89, test acc:0.6971
# epoch:174, train acc:0.89, test acc:0.7032
# epoch:175, train acc:0.89, test acc:0.7095
# epoch:176, train acc:0.9, test acc:0.7083
# epoch:177, train acc:0.8933333333333333, test acc:0.7012
# epoch:178, train acc:0.9, test acc:0.709
# epoch:179, train acc:0.9133333333333333, test acc:0.7097
# epoch:180, train acc:0.9, test acc:0.7078
# epoch:181, train acc:0.8966666666666666, test acc:0.7035
# epoch:182, train acc:0.8966666666666666, test acc:0.7067
# epoch:183, train acc:0.88, test acc:0.6959
# epoch:184, train acc:0.8833333333333333, test acc:0.7023
# epoch:185, train acc:0.8933333333333333, test acc:0.7084
# epoch:186, train acc:0.89, test acc:0.7039
# epoch:187, train acc:0.9, test acc:0.7057
# epoch:188, train acc:0.9033333333333333, test acc:0.7051
# epoch:189, train acc:0.9, test acc:0.7045
# epoch:190, train acc:0.9, test acc:0.6983
# epoch:191, train acc:0.9, test acc:0.7011
# epoch:192, train acc:0.9033333333333333, test acc:0.7077
# epoch:193, train acc:0.9033333333333333, test acc:0.7045
# epoch:194, train acc:0.9166666666666666, test acc:0.7096
# epoch:195, train acc:0.91, test acc:0.7088
# epoch:196, train acc:0.9133333333333333, test acc:0.7099
# epoch:197, train acc:0.9, test acc:0.7057
# epoch:198, train acc:0.9066666666666666, test acc:0.7127
# epoch:199, train acc:0.91, test acc:0.7097
# epoch:200, train acc:0.9033333333333333, test acc:0.709
